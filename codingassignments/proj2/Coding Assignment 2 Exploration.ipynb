# %%
import pandas as pd
import numpy as np

# %%
results = pd.read_csv("results_pct_20181106.txt", sep='\t', lineterminator='\r')
results.head(5)
# Out:
#        County Election Date Precinct  Contest Group ID Contest Type  \
# 0  \nALAMANCE    11/06/2018      064            1228.0            S
# 1  \nALAMANCE    11/06/2018      03N            1228.0            S
# 2  \nALAMANCE    11/06/2018      03S            1228.0            S
# 3  \nALAMANCE    11/06/2018       04            1228.0            S
# 4  \nALAMANCE    11/06/2018      035            1228.0            S
#
#                        Contest Name               Choice Choice Party  \
# 0  NC COURT OF APPEALS JUDGE SEAT 3  Michael Monaco, Sr.          LIB
# 1  NC COURT OF APPEALS JUDGE SEAT 3  Michael Monaco, Sr.          LIB
# 2  NC COURT OF APPEALS JUDGE SEAT 3  Michael Monaco, Sr.          LIB
# 3  NC COURT OF APPEALS JUDGE SEAT 3  Michael Monaco, Sr.          LIB
# 4  NC COURT OF APPEALS JUDGE SEAT 3  Michael Monaco, Sr.          LIB
#
#    Vote For  Election Day  One Stop  Absentee by Mail  Provisional  \
# ...

# %%
district9 = results[results['Contest Name'] == 'US HOUSE OF REPRESENTATIVES DISTRICT 09']
district9.head(5)
# Out:
#          County Election Date Precinct  Contest Group ID Contest Type  \
# 12853  \nBLADEN    11/06/2018      P45            1183.0            S
# 12854  \nBLADEN    11/06/2018     P202            1183.0            S
# 12855  \nBLADEN    11/06/2018      P60            1183.0            S
# 12856  \nBLADEN    11/06/2018      P35            1183.0            S
# 12857  \nBLADEN    11/06/2018      P15            1183.0            S
#
#                                   Contest Name        Choice Choice Party  \
# 12853  US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
# 12854  US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
# 12855  US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
# 12856  US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
# 12857  US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
#
#        Vote For  Election Day  One Stop  Absentee by Mail  Provisional  \
# ...

# %%
absentees = district9[district9['Precinct'] == 'ABSENTEE']
absentees.head(5)
# Out:
#           County Election Date  Precinct  Contest Group ID Contest Type  \
# 12864   \nBLADEN    11/06/2018  ABSENTEE            1183.0            S
# 12868   \nBLADEN    11/06/2018  ABSENTEE            1183.0            S
# 12883   \nBLADEN    11/06/2018  ABSENTEE            1183.0            S
# 145606   \nUNION    11/06/2018  ABSENTEE            1183.0            S
# 145661   \nUNION    11/06/2018  ABSENTEE            1183.0            S
#
#                                    Contest Name        Choice Choice Party  \
# 12864   US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
# 12868   US HOUSE OF REPRESENTATIVES DISTRICT 09    Jeff Scott          LIB
# 12883   US HOUSE OF REPRESENTATIVES DISTRICT 09   Mark Harris          REP
# 145606  US HOUSE OF REPRESENTATIVES DISTRICT 09  Dan McCready          DEM
# 145661  US HOUSE OF REPRESENTATIVES DISTRICT 09    Jeff Scott          LIB
#
#         Vote For  Election Day  One Stop  Absentee by Mail  Provisional  \
# ...

# %%
absentees.groupby("Choice Party").agg({"Absentee by Mail": np.sum})
# Out:
#               Absentee by Mail
# Choice Party
# DEM                      405.0
# LIB                       12.0
# REP                      515.0

# %%
absentees[(absentees['Choice Party'] == " ") & ((absentees['Choice'] != "For") | \
                                                (absentees['Choice'] != "Against"))]
# Out:
#               County Election Date  Precinct  Contest Group ID Contest Type  \
# 714       \nBEAUFORT    11/06/2018  ABSENTEE               3.0            C
# 779       \nBEAUFORT    11/06/2018  ABSENTEE               3.0            C
# 791       \nBEAUFORT    11/06/2018  ABSENTEE               3.0            C
# 8735        \nBLADEN    11/06/2018  ABSENTEE            1420.0            S
# 8743        \nBLADEN    11/06/2018  ABSENTEE            1420.0            S
# 8775        \nBLADEN    11/06/2018  ABSENTEE            1421.0            S
# 8782        \nBLADEN    11/06/2018  ABSENTEE            1421.0            S
# 8800        \nBLADEN    11/06/2018  ABSENTEE            1422.0            S
# 8822        \nBLADEN    11/06/2018  ABSENTEE            1422.0            S
# 8859        \nBLADEN    11/06/2018  ABSENTEE            1423.0            S
# 8865        \nBLADEN    11/06/2018  ABSENTEE            1423.0            S
# ...
